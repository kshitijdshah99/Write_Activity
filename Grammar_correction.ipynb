# %%
pip install -U git+https://github.com/PrithivirajDamodaran/Gramformer.git
# Out:
# ...
#   Cloning https://github.com/PrithivirajDamodaran/Gramformer.git to /tmp/pip-req-build-9tx8ryhk
#   Running command git clone --filter=blob:none --quiet https://github.com/PrithivirajDamodaran/Gramformer.git /tmp/pip-req-build-9tx8ryhk
#   Resolved https://github.com/PrithivirajDamodaran/Gramformer.git to commit 23425cd2e98a919384cab6156af8adf1c9d0639a
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.3/499.3 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 19.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 20.6 MB/s eta 0:00:00
# ...
#   Created wheel for gramformer: filename=gramformer-1.0-py3-none-any.whl size=4463 sha256=a70188f4f8c86fa429ed5288a713f46235a64c9fb3aadf78b984e9a9a2e4d843
#   Stored in directory: /tmp/pip-ephem-wheel-cache-r48ca8r9/wheels/76/44/15/e79b5dc4f5c897b2054e6a8e357f6de157b9554f072a2e56ea
# Successfully built gramformer
# ...

# %%
from gramformer import Gramformer
import torch

def set_seed(seed):
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

# %%
gf = Gramformer(models = 1, use_gpu=False) # 0=detector, 1=highlighter, 2=corrector, 3=all
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py:720: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.89k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py:466: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]
# [Gramformer] Grammar error correct/highlight model loaded..

# %%
influent_sentences = [
    "He are moving here.",
    "I am doing fine. How is you?",
    "How is they?",
    "Write activity is promoted creativity for children",
    "the collection of letters was original used by the ancient Romans",
    "We enjoys horror movies",
    "Anna and Mike is going skiing",
    "I walk to the store and I bought milk",
    "Sugar is a nice dektop environment for childs",
    "Adding AI-assistant to Sugar platform had have been an successful idea",
    "what be the reason for everyone leave the company",
]

# %%
for influent_sentence in influent_sentences:
    corrected_sentences = gf.correct(influent_sentence, max_candidates=1)
    print("[Input] ", influent_sentence)
    for corrected_sentence in corrected_sentences:
      print("[Correction] ",corrected_sentence)
    print("-" *100)
# Out:
# [Input]  He are moving here.
# [Correction]  He is moving here.
# ----------------------------------------------------------------------------------------------------
# [Input]  I am doing fine. How is you?
# [Correction]  I am doing fine. How are you?
# ----------------------------------------------------------------------------------------------------
# [Input]  How is they?
# [Correction]  How are they?
# ----------------------------------------------------------------------------------------------------
# [Input]  Write activity is promoted creativity for children
# [Correction]  Write activity promotes creativity for children.
# ----------------------------------------------------------------------------------------------------
# [Input]  the collection of letters was original used by the ancient Romans
# [Correction]  the collection of letters was originally used by the ancient Romans
# ...
